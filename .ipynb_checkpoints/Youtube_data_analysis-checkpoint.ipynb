# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
from googleapiclient.discovery import build
import api_config

# %% [markdown]
# ## Scraping data from Youtube with Api

# %%
channel_id = 'UC5_Q895CBrZLP7hm83uexjg'
youtube = build('youtube', 'v3', developerKey=api_config.yt_Api_key)
youtube_2 = build('youtube', 'v3', developerKey=api_config.yt_Api_key2)

# %%
def search_ytchannel_with_keyword(youtube, query='data science | data analyst | data scientist | machine learning'):
    request = youtube.search().list(
        part="snippet",
        maxResults=100,
        q=query,
        type='channel'
    )
    response = request.execute()
    channels = []
    for i in range(len(response['items'])):
        data = dict(channel_title = response['items'][i]['snippet']['channelTitle'],
                    channel_id = response['items'][i]['snippet']['channelId'])
        channels.append(data)
    next_page_token = response.get('nextPageToken')
    more_pages = True

    while more_pages:
        if next_page_token is None:
            more_pages = False
        elif len(response['items']) == 1000:
            break
        else:
            request = youtube.search().list(
            part="snippet",
            maxResults=100,
        q=query,
        type='channel,playlist,videos',
        pageToken = next_page_token
    )
        response = request.execute()

        for i in range(len(response['items'])):
            data = dict(channel_title = response['items'][i]['snippet']['channelTitle'],
                        channel_id = response['items'][i]['snippet']['channelId'])
        
            channels.append(data)
        next_page_token = response.get('nextPageToken')
    
    return channels

# %%
fresh_json_data = search_ytchannel_with_keyword(youtube_2, query='data science | data analyst')

# %%
file_name = 'channels_2_data.json'
with open(file_name, 'w') as file:
    json.dump(fresh_json_data, file)

# %%
request = youtube.search().list(
        part="snippet",
        maxResults=100,
        q="data science" or "data analysis" or "SQL" or "machine learning" or "data scientist",
        type='channel,playlist,videos'
    )
response = request.execute()
channels = []
for i in range(len(response['items'])):
    data = dict(channel_title = response['items'][i]['snippet']['channelTitle'],
                channel_id = response['items'][i]['snippet']['channelId'])
#                 subscribers = response['items'][i]['statistics']['subscriberCount'])

    channels.append(data)
next_page_token = response.get('nextPageToken')
more_pages = True

while more_pages:
    if next_page_token is None:
        more_pages = False
    else:
        request = youtube.search().list(
        part="snippet",
        maxResults=100,
        q="data science" or "data analysis" or "SQL" or "machine learning" or "data scientist",
        type='channel,playlist,videos',
        pageToken = next_page_token
    )
        response = request.execute()

    for i in range(len(response['items'])):
        data = dict(channel_title = response['items'][i]['snippet']['channelTitle'],
                    channel_id = response['items'][i]['snippet']['channelId'])
        
        channels.append(data)
    next_page_token = response.get('nextPageToken')

print(len(channels))

# %%
file_name = 'Yt_data.json'
with open(file_name, 'w') as file:
    json.dump(channels, file)

# %%
with open('Yt_data.json', 'r') as file:
    youtube = json.load(file)

# %%
with open('channels_2_data.json', 'r') as file:
    youtube_1 = json.load(file)

# %%
print(len(youtube))
print(len(youtube_1))
# Out:
# 602
# 555

# %%
df_1 = pd.DataFrame(youtube)
df_2 = pd.DataFrame(youtube_1)

# %%
df_1.head()
# Out:
#                                        channel_title                channel_id
# 0  DSN- Data Scientists Network(Data Science Nige...  UCTi2xuVi9CLx9QryIJYLbaQ
# 1                                   freeCodeCamp.org  UC8butISFwT-Wl7EV0hUK0BQ
# 2                                         codebasics  UCh9nVJoWXmFb7sLApWGcLPQ
# 3                                      Steve Brunton  UCm5mt-A4w61lknZ9lCsZtBw
# 4                                     Data Professor  UCV8e2g4IWQqK71bbzGDEI4Q

# %%
df_2 = df_2.drop_duplicates()

# %%
df_1 = df_1.drop_duplicates()

# %%
new_df = pd.concat([df_1, df_2])
new_df
# Out:
#                                          channel_title  \
# 0    DSN- Data Scientists Network(Data Science Nige...
# 1                                     freeCodeCamp.org
# 2                                           codebasics
# 3                                        Steve Brunton
# 4                                       Data Professor
# ..                                                 ...
# 548                                         Tony Games
# 549                                            Sheldon
# 550                                 DɾJØҽ༒Pɨυֆ༒Mᗩɳᗩƙɨʅ
# 551                                     Joshua Pavelko
# 552                                        Getloose360
#
#                    channel_id
# 0    UCTi2xuVi9CLx9QryIJYLbaQ
# 1    UC8butISFwT-Wl7EV0hUK0BQ
# 2    UCh9nVJoWXmFb7sLApWGcLPQ
# 3    UCm5mt-A4w61lknZ9lCsZtBw
# 4    UCV8e2g4IWQqK71bbzGDEI4Q
# ..                        ...
# 548  UC9SDde41KHNC-VGw0qJ57mQ
# 549  UCtE0e8G-9zjwrQrug3Mra_A
# 550  UCsPQUCWRjWWGFvdyhjNLJ2A
# 551  UCEcc1trh3yFCcXHA1YQOezw
# 552  UCRT5dsm8Sbzlmd4S8ueyZqg
#
# [969 rows x 2 columns]

# %%
duplicate = new_df[new_df.duplicated()]
duplicate
# Out:
#                                      channel_title                channel_id
# 16                                365 Data Science  UCEBpSZhI1X8WaP-kY_2LLcg
# 20   MarinStatsLectures-R Programming & Statistics  UCaNIxVagLhqupvUiDK01Mgg
# 21                                365 Data Science  UCEBpSZhI1X8WaP-kY_2LLcg
# 24                                  Data Professor  UCV8e2g4IWQqK71bbzGDEI4Q
# 41                                      ritvikmath  UCUcpVoi5KkJmnE3bvEhHR0Q
# ..                                             ...                       ...
# 478                                     Pacmann AI  UC5oiB8wDG17W8XALdLjlFEw
# 502                                    Simplilearn  UCsvqVGtbbyHaMoevxPAq9Fg
# 514                                    Techcanvass  UCDHsj-2kb_bGk_Dr3ktSSbg
# 553                             DɾJØҽ༒Pɨυֆ༒Mᗩɳᗩƙɨʅ  UCsPQUCWRjWWGFvdyhjNLJ2A
# 554                                    Getloose360  UCRT5dsm8Sbzlmd4S8ueyZqg
#
# [230 rows x 2 columns]

# %%
new_df = new_df.drop_duplicates()
new_df
# Out:
#                                          channel_title  \
# 0    DSN- Data Scientists Network(Data Science Nige...
# 1                                     freeCodeCamp.org
# 2                                           codebasics
# 3                                        Steve Brunton
# 4                                       Data Professor
# ..                                                 ...
# 548                                         Tony Games
# 549                                            Sheldon
# 550                                 DɾJØҽ༒Pɨυֆ༒Mᗩɳᗩƙɨʅ
# 551                                     Joshua Pavelko
# 552                                        Getloose360
#
#                    channel_id
# 0    UCTi2xuVi9CLx9QryIJYLbaQ
# 1    UC8butISFwT-Wl7EV0hUK0BQ
# 2    UCh9nVJoWXmFb7sLApWGcLPQ
# 3    UCm5mt-A4w61lknZ9lCsZtBw
# 4    UCV8e2g4IWQqK71bbzGDEI4Q
# ..                        ...
# 548  UC9SDde41KHNC-VGw0qJ57mQ
# 549  UCtE0e8G-9zjwrQrug3Mra_A
# 550  UCsPQUCWRjWWGFvdyhjNLJ2A
# 551  UCEcc1trh3yFCcXHA1YQOezw
# 552  UCRT5dsm8Sbzlmd4S8ueyZqg
#
# [927 rows x 2 columns]

# %%
new_df.to_csv('youtube_channel_ids.csv')

# %%
new_df_1 = pd.read_csv('youtube_channel_ids.csv', index_col='Unnamed: 0')

# %%
new_df_1
# Out:
#                                          channel_title  \
# 0    DSN- Data Scientists Network(Data Science Nige...
# 1                                     freeCodeCamp.org
# 2                                           codebasics
# 3                                        Steve Brunton
# 4                                       Data Professor
# ..                                                 ...
# 548                                         Tony Games
# 549                                            Sheldon
# 550                                 DɾJØҽ༒Pɨυֆ༒Mᗩɳᗩƙɨʅ
# 551                                     Joshua Pavelko
# 552                                        Getloose360
#
#                    channel_id
# 0    UCTi2xuVi9CLx9QryIJYLbaQ
# 1    UC8butISFwT-Wl7EV0hUK0BQ
# 2    UCh9nVJoWXmFb7sLApWGcLPQ
# 3    UCm5mt-A4w61lknZ9lCsZtBw
# 4    UCV8e2g4IWQqK71bbzGDEI4Q
# ..                        ...
# 548  UC9SDde41KHNC-VGw0qJ57mQ
# 549  UCtE0e8G-9zjwrQrug3Mra_A
# 550  UCsPQUCWRjWWGFvdyhjNLJ2A
# 551  UCEcc1trh3yFCcXHA1YQOezw
# 552  UCRT5dsm8Sbzlmd4S8ueyZqg
#
# [927 rows x 2 columns]

# %%
yt_channe_ids_1 = df_2.channel_id.tolist()
print(yt_channe_ids_1)

# %%
yt_channe_ids_2 = df_1.channel_id.tolist()
print(len(yt_channe_ids_2))
# Out:
# 488

# %%
channel_ids = new_df.channel_id.tolist()
print(channel_ids)

# %%
def get_channel_stats(youtube, channel_ids):
     data = []
     for id in channel_ids:
       try:
              request = youtube.channels().list(
                     part="snippet,contentDetails,statistics",
                     maxResults=50,
                     id = id )
              response = request.execute()
    
              for i in range(len(response['items'])):
                     data_dict = dict(channel_name = response['items'][i]['snippet']['title'],
                                      subscribers = response['items'][i]['statistics']['subscriberCount'],
                                      views = response['items'][i]['statistics']['viewCount'],
                                      videos = response['items'][i]['statistics']['videoCount'],
                                      published_date = response['items'][i]['snippet']['publishedAt'])
                     data.append(data_dict)
    
              next_page_token = response.get('nextPageToken')
              more_pages = True

              while more_pages:
                     if next_page_token is None:
                            more_pages = False
                     else:
                            request = youtube.channels().list(
                                   part="snippet,contentDetails,statistics",
                                   maxResults=50,
                                   id= id,
                                   pageToken = next_page_token)
                            response = request.execute()

                     for i in range(len(response['items'])):
                            data_dict = dict(channel_name = response['items'][i]['snippet']['title'],
                                             subscribers = response['items'][i]['statistics']['subscriberCount'],
                                             views = response['items'][i]['statistics']['viewCount'],
                                             videos = response['items'][i]['statistics']['videoCount'],
                                             published_date = response['items'][i]['snippet']['publishedAt'])
                            data.append(data_dict)
                     next_page_token = response.get('nextPageToken')
       except KeyError as ke:
              print(ke)
              pass

     return data

# %%
new_ids = [ids for ids in channel_ids]
new_ids

# %%
ids = ['UCTi2xuVi9CLx9QryIJYLbaQ',
 'UC8butISFwT-Wl7EV0hUK0BQ',
 'UCh9nVJoWXmFb7sLApWGcLPQ',
 'UCm5mt-A4w61lknZ9lCsZtBw',
 'UCV8e2g4IWQqK71bbzGDEI4Q']

# %%
json_data = get_channel_stats(youtube_2, channel_ids)
# Out:
# 'items'
# 'items'

# %%
print(len(json_data))
# Out:
# 1850

# %%
file_name = 'full_yt_channels_stats.json'
with open(file_name, 'w') as file:
    json.dump(json_data, file)

# %%
file_name = 'first_yt_channels_stats.json'
with open(file_name, 'w') as file:
    json.dump(json_data, file)

# %%
file_name = 'second_yt_channels_stats.json'
with open(file_name, 'w') as file:
    json.dump(json_data, file)

# %%
with open('first_yt_channels_stats.json') as file:
    channel_stats_data_1 = json.load(file)

# %%
with open('second_yt_channels_stats.json') as file:
    channel_stats_data_2 = json.load(file)

# %%
with open('full_yt_channels_stats.json') as file:
    full_channel_stats_data = json.load(file)

# %%
full_channel_stats_df = pd.DataFrame(full_channel_stats_data)
full_channel_stats_df.head()
# Out:
#                                         channel_name subscribers      views  \
# 0  DSN- Data Scientists Network(Data Science Nige...       10000     707922
# 1  DSN- Data Scientists Network(Data Science Nige...       10000     707922
# 2                                   freeCodeCamp.org     6150000  412434264
# 3                                   freeCodeCamp.org     6150000  412434264
# 4                                         codebasics      645000   42421146
#
#   videos        published_date
# 0    278  2017-09-13T16:36:47Z
# 1    278  2017-09-13T16:36:47Z
# 2   1341  2014-12-16T21:18:48Z
# 3   1341  2014-12-16T21:18:48Z
# 4    539  2015-11-07T17:29:46Z

# %%
channels_stat_df_1 = pd.DataFrame(channel_stats_data_1)
channels_stat_df_2 = pd.DataFrame(channel_stats_data_2)

# %%
channels_stat_df_1 = channels_stat_df_1.drop_duplicates()
channels_stat_df_1
# Out:
#               channel_name subscribers     views videos
# 0         Alex The Analyst      268000  10700064    160
# 2            Luke Barousse      226000  10414557     77
# 4    Thu Vu data analytics       48900   1175293     43
# 6       Shashank Kalanithi      101000   4356578    141
# 8            Sundas Khalid       81700   2844710     58
# ..                     ...         ...       ...    ...
# 952             Tony Games           0         0      0
# 954                Sheldon           0         0      0
# 956     DɾJØҽ༒Pɨυֆ༒Mᗩɳᗩƙɨʅ        3740     52667      7
# 958         Joshua Pavelko           0         0      0
# 960            Getloose360          15         0      0
#
# [481 rows x 4 columns]

# %%
channels_stat_df_2 = channels_stat_df_2.drop_duplicates()
channels_stat_df_2
# Out:
#                                           channel_name subscribers      views  \
# 0    DSN- Data Scientists Network(Data Science Nige...       10000     707872
# 2                                     freeCodeCamp.org     6150000  411947427
# 4                                           codebasics      645000   42370321
# 6                                        Steve Brunton      215000   11893145
# 8                                       Data Professor      132000    3384752
# ..                                                 ...         ...        ...
# 964                         19_154-ALFINI NURIL INSANI           6        122
# 966                                         Lets Learn           8        162
# 968                                Daily Science Video        2890         56
# 970                                        Jakir Fakir           0          0
# 972                           14 High School Sports 41           0          0
#
#     videos
# 0      278
# 2     1341
# 4      538
# 6      379
# 8      290
# ..     ...
# 964      3
# 966      7
# 968      6
# 970      1
# 972      0
#
# [487 rows x 4 columns]

# %%
merged_stats_data = pd.concat([channels_stat_df_1, channels_stat_df_2])
merged_stats_data
# Out:
#                    channel_name subscribers     views videos
# 0              Alex The Analyst      268000  10700064    160
# 2                 Luke Barousse      226000  10414557     77
# 4         Thu Vu data analytics       48900   1175293     43
# 6            Shashank Kalanithi      101000   4356578    141
# 8                 Sundas Khalid       81700   2844710     58
# ..                          ...         ...       ...    ...
# 964  19_154-ALFINI NURIL INSANI           6       122      3
# 966                  Lets Learn           8       162      7
# 968         Daily Science Video        2890        56      6
# 970                 Jakir Fakir           0         0      1
# 972    14 High School Sports 41           0         0      0
#
# [968 rows x 4 columns]

# %%
merged_channel_stats_df = full_channel_stats_df.merge(new_df, left_on='channel_name', right_on='channel_title', how='left')

# %%
merged_channel_stats_df
# Out:
#                                            channel_name subscribers  \
# 0     DSN- Data Scientists Network(Data Science Nige...       10000
# 1     DSN- Data Scientists Network(Data Science Nige...       10000
# 2                                      freeCodeCamp.org     6150000
# 3                                      freeCodeCamp.org     6150000
# 4                                            codebasics      645000
# ...                                                 ...         ...
# 2213                                 DɾJØҽ༒Pɨυֆ༒Mᗩɳᗩƙɨʅ        3740
# 2214                                     Joshua Pavelko           0
# 2215                                     Joshua Pavelko           0
# 2216                                        Getloose360          15
# 2217                                        Getloose360          15
#
#           views videos        published_date  \
# 0        707922    278  2017-09-13T16:36:47Z
# 1        707922    278  2017-09-13T16:36:47Z
# 2     412434264   1341  2014-12-16T21:18:48Z
# 3     412434264   1341  2014-12-16T21:18:48Z
# 4      42421146    539  2015-11-07T17:29:46Z
# ...         ...    ...                   ...
# 2213      52669      7  2014-02-17T20:28:41Z
# 2214          0      0  2013-01-27T22:51:02Z
# 2215          0      0  2013-01-27T22:51:02Z
# 2216          0      0  2007-09-29T17:00:59Z
# 2217          0      0  2007-09-29T17:00:59Z
#
#                                           channel_title  \
# 0     DSN- Data Scientists Network(Data Science Nige...
# 1     DSN- Data Scientists Network(Data Science Nige...
# 2                                      freeCodeCamp.org
# 3                                      freeCodeCamp.org
# 4                                            codebasics
# ...                                                 ...
# 2213                                 DɾJØҽ༒Pɨυֆ༒Mᗩɳᗩƙɨʅ
# 2214                                     Joshua Pavelko
# 2215                                     Joshua Pavelko
# 2216                                        Getloose360
# 2217                                        Getloose360
#
#                     channel_id
# 0     UCTi2xuVi9CLx9QryIJYLbaQ
# 1     UCTi2xuVi9CLx9QryIJYLbaQ
# 2     UC8butISFwT-Wl7EV0hUK0BQ
# 3     UC8butISFwT-Wl7EV0hUK0BQ
# 4     UCh9nVJoWXmFb7sLApWGcLPQ
# ...                        ...
# 2213  UCsPQUCWRjWWGFvdyhjNLJ2A
# 2214  UCEcc1trh3yFCcXHA1YQOezw
# 2215  UCEcc1trh3yFCcXHA1YQOezw
# 2216  UCRT5dsm8Sbzlmd4S8ueyZqg
# 2217  UCRT5dsm8Sbzlmd4S8ueyZqg
#
# [2218 rows x 7 columns]

# %%
merged_channel_stats_df.drop_duplicates(inplace=True)
merged_channel_stats_df
# Out:
#                                            channel_name subscribers  \
# 0     DSN- Data Scientists Network(Data Science Nige...       10000
# 2                                      freeCodeCamp.org     6150000
# 4                                            codebasics      645000
# 6                                         Steve Brunton      215000
# 8                                        Data Professor      132000
# ...                                                 ...         ...
# 2208                                         Tony Games           0
# 2210                                            Sheldon           0
# 2212                                 DɾJØҽ༒Pɨυֆ༒Mᗩɳᗩƙɨʅ        3740
# 2214                                     Joshua Pavelko           0
# 2216                                        Getloose360          15
#
#           views videos        published_date  \
# 0        707922    278  2017-09-13T16:36:47Z
# 2     412434264   1341  2014-12-16T21:18:48Z
# 4      42421146    539  2015-11-07T17:29:46Z
# 6      11902956    379  2011-10-07T15:57:41Z
# 8       3388292    290  2019-08-17T15:59:56Z
# ...         ...    ...                   ...
# 2208          0      0  2012-02-03T18:59:46Z
# 2210          0      0  2012-09-20T16:36:58Z
# 2212      52669      7  2014-02-17T20:28:41Z
# 2214          0      0  2013-01-27T22:51:02Z
# 2216          0      0  2007-09-29T17:00:59Z
#
#                                           channel_title  \
# 0     DSN- Data Scientists Network(Data Science Nige...
# 2                                      freeCodeCamp.org
# 4                                            codebasics
# 6                                         Steve Brunton
# 8                                        Data Professor
# ...                                                 ...
# 2208                                         Tony Games
# 2210                                            Sheldon
# 2212                                 DɾJØҽ༒Pɨυֆ༒Mᗩɳᗩƙɨʅ
# 2214                                     Joshua Pavelko
# 2216                                        Getloose360
#
#                     channel_id
# 0     UCTi2xuVi9CLx9QryIJYLbaQ
# 2     UC8butISFwT-Wl7EV0hUK0BQ
# 4     UCh9nVJoWXmFb7sLApWGcLPQ
# 6     UCm5mt-A4w61lknZ9lCsZtBw
# 8     UCV8e2g4IWQqK71bbzGDEI4Q
# ...                        ...
# 2208  UC9SDde41KHNC-VGw0qJ57mQ
# 2210  UCtE0e8G-9zjwrQrug3Mra_A
# 2212  UCsPQUCWRjWWGFvdyhjNLJ2A
# 2214  UCEcc1trh3yFCcXHA1YQOezw
# 2216  UCRT5dsm8Sbzlmd4S8ueyZqg
#
# [1109 rows x 7 columns]

# %%
merged_channel_stats_df.to_csv('complete-ds-yt-channel-data.csv')

# %% [markdown]
# ## Cleaning

# %%
merged_channel_stats_df.dtypes
# Out:
# channel_name      object
# subscribers       object
# views             object
# videos            object
# published_date    object
# channel_title     object
# channel_id        object
# dtype: object

# %%
merged_channel_stats_df['subscribers'] = pd.to_numeric(merged_channel_stats_df['subscribers'])
merged_channel_stats_df['views'] = pd.to_numeric(merged_channel_stats_df['views'])
merged_channel_stats_df['videos'] = pd.to_numeric(merged_channel_stats_df['videos'])
merged_channel_stats_df['published_date'] = pd.to_datetime(merged_channel_stats_df['published_date'])
merged_channel_stats_df.dtypes
# Out:
# channel_name                   object
# subscribers                     int64
# views                           int64
# videos                          int64
# published_date    datetime64[ns, UTC]
# channel_title                  object
# channel_id                     object
# dtype: object

# %%
overall_merged.to_csv('ds_youtube_channel_data.csv')
